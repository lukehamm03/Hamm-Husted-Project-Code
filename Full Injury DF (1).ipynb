# %%
### 2024 Data###
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
options = Options()
options.headless = True
chromedriver_path = '/Users/owner/Documents/WC_DS/chromedriver-mac-arm64/chromedriver'
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service, options=options)
url = 'https://www.fangraphs.com/roster-resource/injury-report?season=2024&timeframe=all'

driver.get(url)
time.sleep(15)
soup = BeautifulSoup(driver.page_source, 'html.parser')
team_tables = soup.find_all('div', class_='table-scroll')
all_rows = []
for team_table in team_tables:
    headers = [header.text.strip() for header in team_table.find_all('th')]
    headers = headers[:10]  # You may want to trim headers if they have extra columns

    rows = []
    for row in team_table.find_all('tr')[1:]:  # Skip the header row
        columns = row.find_all('td')
        if len(columns) > 0:
            row_data = [col.text.strip() for col in columns]
            rows.append(row_data)
    all_rows.extend(rows)

df = pd.DataFrame(all_rows, columns=headers)
driver.quit()

# Filtering for arm injuries and pitchers
filtered_df = df[df['Injury / Surgery'].str.contains('Tommy John|Elbow|Shoulder|Forearm', case=False, na=False)]
filtered_df_p = filtered_df[filtered_df['Pos'].str.contains('SP|RP', case=False, na=False)]

# Data cleaning
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '23", na=False), 'Injury / Surgery Date'] = '01/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '23", na=False), 'Injury / Surgery Date'] = '02/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '23", na=False), 'Injury / Surgery Date'] = '03/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '23", na=False), 'Injury / Surgery Date'] = '04/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '23", na=False), 'Injury / Surgery Date'] = '05/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '23", na=False), 'Injury / Surgery Date'] = '06/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '23", na=False), 'Injury / Surgery Date'] = '07/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '23", na=False), 'Injury / Surgery Date'] = '08/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '23", na=False), 'Injury / Surgery Date'] = '09/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '23", na=False), 'Injury / Surgery Date'] = '10/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '23", na=False), 'Injury / Surgery Date'] = '11/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '23", na=False), 'Injury / Surgery Date'] = '12/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '24", na=False), 'Injury / Surgery Date'] = '01/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '24", na=False), 'Injury / Surgery Date'] = '02/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '24", na=False), 'Injury / Surgery Date'] = '03/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '24", na=False), 'Injury / Surgery Date'] = '04/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr' '24", na=False), 'Injury / Surgery Date'] = '04/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '24", na=False), 'Injury / Surgery Date'] = '05/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '24", na=False), 'Injury / Surgery Date'] = '06/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '24", na=False), 'Injury / Surgery Date'] = '07/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '24", na=False), 'Injury / Surgery Date'] = '08/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '24", na=False), 'Injury / Surgery Date'] = '09/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '24", na=False), 'Injury / Surgery Date'] = '10/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '24", na=False), 'Injury / Surgery Date'] = '11/01/24'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '24", na=False), 'Injury / Surgery Date'] = '12/01/24'

filtered_df_p['Injury / Surgery Date'] = pd.to_datetime(filtered_df_p['Injury / Surgery Date'], format='%m/%d/%y')
cutoff_date = pd.to_datetime('01/01/24', format='%m/%d/%y')
final_df_24 = filtered_df_p[filtered_df_p['Injury / Surgery Date'] > cutoff_date]

final_df_24.reset_index(drop=True)
# Out:
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/923927762.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '23", na=False), 'Injury / Surgery Date'] = '01/01/23'
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/923927762.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '23", na=False), 'Injury / Surgery Date'] = '02/01/23'
# ...

# %%
### 2023 Data###
options = Options()
options.headless = True  # Run in headless mode (without opening a browser window)
chromedriver_path = '/Users/owner/Documents/WC_DS/chromedriver-mac-arm64/chromedriver'
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service, options=options)
url = url = 'https://www.fangraphs.com/roster-resource/injury-report?timeframe=all&season=2023'
driver.get(url)

time.sleep(15)
soup = BeautifulSoup(driver.page_source, 'html.parser')
team_tables = soup.find_all('div', class_='table-scroll')
all_rows = []

for team_table in team_tables:
    headers = [header.text.strip() for header in team_table.find_all('th')]
    headers = headers[:10]
    rows = []
    for row in team_table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) > 0:
            row_data = [col.text.strip() for col in columns]
            rows.append(row_data)
    all_rows.extend(rows)

df = pd.DataFrame(all_rows, columns=headers)
driver.quit()

# Filtering for arm injuries and pitchers
filtered_df = df[df['Injury / Surgery'].str.contains('Tommy John|Elbow|Shoulder|Forearm', case=False, na=False)]
filtered_df_p = filtered_df[filtered_df['Pos'].str.contains('SP|RP', case=False, na=False)]

# Data cleaning
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '23", na=False), 'Injury / Surgery Date'] = '01/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '23", na=False), 'Injury / Surgery Date'] = '02/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '23", na=False), 'Injury / Surgery Date'] = '03/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '23", na=False), 'Injury / Surgery Date'] = '04/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '23", na=False), 'Injury / Surgery Date'] = '05/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '23", na=False), 'Injury / Surgery Date'] = '06/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '23", na=False), 'Injury / Surgery Date'] = '07/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '23", na=False), 'Injury / Surgery Date'] = '08/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '23", na=False), 'Injury / Surgery Date'] = '09/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '23", na=False), 'Injury / Surgery Date'] = '10/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '23", na=False), 'Injury / Surgery Date'] = '11/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '23", na=False), 'Injury / Surgery Date'] = '12/01/23'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '22", na=False), 'Injury / Surgery Date'] = '01/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '22", na=False), 'Injury / Surgery Date'] = '02/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '22", na=False), 'Injury / Surgery Date'] = '03/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '22", na=False), 'Injury / Surgery Date'] = '04/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '22", na=False), 'Injury / Surgery Date'] = '05/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '22", na=False), 'Injury / Surgery Date'] = '06/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '22", na=False), 'Injury / Surgery Date'] = '07/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '22", na=False), 'Injury / Surgery Date'] = '08/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '22", na=False), 'Injury / Surgery Date'] = '09/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '22", na=False), 'Injury / Surgery Date'] = '10/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '22", na=False), 'Injury / Surgery Date'] = '11/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '22", na=False), 'Injury / Surgery Date'] = '12/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '21", na=False), 'Injury / Surgery Date'] = '01/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '21", na=False), 'Injury / Surgery Date'] = '02/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '21", na=False), 'Injury / Surgery Date'] = '03/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '21", na=False), 'Injury / Surgery Date'] = '04/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '21", na=False), 'Injury / Surgery Date'] = '05/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '21", na=False), 'Injury / Surgery Date'] = '06/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '21", na=False), 'Injury / Surgery Date'] = '07/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '21", na=False), 'Injury / Surgery Date'] = '08/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '21", na=False), 'Injury / Surgery Date'] = '09/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '21", na=False), 'Injury / Surgery Date'] = '10/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '21", na=False), 'Injury / Surgery Date'] = '11/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '21", na=False), 'Injury / Surgery Date'] = '12/01/21'
filtered_df_p['Injury / Surgery Date'] = pd.to_datetime(filtered_df_p['Injury / Surgery Date'], format='%m/%d/%y')
cutoff_date = pd.to_datetime('01/01/23', format='%m/%d/%y')
final_df_23 = filtered_df_p[filtered_df_p['Injury / Surgery Date'] > cutoff_date]

final_df_23.reset_index(drop=True)
# Out:
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/1486116913.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '23", na=False), 'Injury / Surgery Date'] = '01/01/23'
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/1486116913.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '23", na=False), 'Injury / Surgery Date'] = '02/01/23'
# ...

# %%
### 2022 Data###
options = Options()
options.headless = True
chromedriver_path = '/Users/owner/Documents/WC_DS/chromedriver-mac-arm64/chromedriver'
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service, options=options)
url = url = 'https://www.fangraphs.com/roster-resource/injury-report?timeframe=all&season=2022'

driver.get(url)
time.sleep(15)
soup = BeautifulSoup(driver.page_source, 'html.parser')
team_tables = soup.find_all('div', class_='table-scroll')
all_rows = []
for team_table in team_tables:
    headers = [header.text.strip() for header in team_table.find_all('th')]
    headers = headers[:10]
    rows = []
    for row in team_table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) > 0:
            row_data = [col.text.strip() for col in columns]
            rows.append(row_data)
    all_rows.extend(rows)

df = pd.DataFrame(all_rows, columns=headers)
driver.quit()

# Filtering for arm injuries and pitchers
filtered_df = df[df['Injury / Surgery'].str.contains('Tommy John|Elbow|Shoulder|Forearm', case=False, na=False)]
filtered_df_p = filtered_df[filtered_df['Pos'].str.contains('SP|RP', case=False, na=False)]

# Data cleaning
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '20", na=False), 'Injury / Surgery Date'] = '01/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '20", na=False), 'Injury / Surgery Date'] = '02/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '20", na=False), 'Injury / Surgery Date'] = '03/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '20", na=False), 'Injury / Surgery Date'] = '04/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '20", na=False), 'Injury / Surgery Date'] = '05/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '20", na=False), 'Injury / Surgery Date'] = '06/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '20", na=False), 'Injury / Surgery Date'] = '07/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '20", na=False), 'Injury / Surgery Date'] = '08/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '20", na=False), 'Injury / Surgery Date'] = '09/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '20", na=False), 'Injury / Surgery Date'] = '10/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '20", na=False), 'Injury / Surgery Date'] = '11/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '20", na=False), 'Injury / Surgery Date'] = '12/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '22", na=False), 'Injury / Surgery Date'] = '01/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '22", na=False), 'Injury / Surgery Date'] = '02/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '22", na=False), 'Injury / Surgery Date'] = '03/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar' 22", na=False), 'Injury / Surgery Date'] = '03/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '22", na=False), 'Injury / Surgery Date'] = '04/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '22", na=False), 'Injury / Surgery Date'] = '05/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '22", na=False), 'Injury / Surgery Date'] = '06/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '22", na=False), 'Injury / Surgery Date'] = '07/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul' 22", na=False), 'Injury / Surgery Date'] = '07/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '22", na=False), 'Injury / Surgery Date'] = '08/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '22", na=False), 'Injury / Surgery Date'] = '09/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '22", na=False), 'Injury / Surgery Date'] = '10/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '22", na=False), 'Injury / Surgery Date'] = '11/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '22", na=False), 'Injury / Surgery Date'] = '12/01/22'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '21", na=False), 'Injury / Surgery Date'] = '01/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '21", na=False), 'Injury / Surgery Date'] = '02/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '21", na=False), 'Injury / Surgery Date'] = '03/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '21", na=False), 'Injury / Surgery Date'] = '04/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '21", na=False), 'Injury / Surgery Date'] = '05/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '21", na=False), 'Injury / Surgery Date'] = '06/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '21", na=False), 'Injury / Surgery Date'] = '07/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '21", na=False), 'Injury / Surgery Date'] = '08/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '21", na=False), 'Injury / Surgery Date'] = '09/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '21", na=False), 'Injury / Surgery Date'] = '10/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '21", na=False), 'Injury / Surgery Date'] = '11/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '21", na=False), 'Injury / Surgery Date'] = '12/01/21'

filtered_df_p['Injury / Surgery Date'] = pd.to_datetime(filtered_df_p['Injury / Surgery Date'], format='%m/%d/%y')
cutoff_date = pd.to_datetime('01/01/22', format='%m/%d/%y')
final_df_22 = filtered_df_p[filtered_df_p['Injury / Surgery Date'] > cutoff_date]

final_df_22.reset_index(drop=True)
# Out:
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/4177314697.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '20", na=False), 'Injury / Surgery Date'] = '01/01/20'
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/4177314697.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '20", na=False), 'Injury / Surgery Date'] = '02/01/20'
# ...

# %%
### 2021 Data###
options = Options()
options.headless = True
chromedriver_path = '/Users/owner/Documents/WC_DS/chromedriver-mac-arm64/chromedriver'
service = Service(chromedriver_path)
driver = webdriver.Chrome(service=service, options=options)
url = url = 'https://www.fangraphs.com/roster-resource/injury-report?timeframe=all&season=2021'

driver.get(url)
time.sleep(15)
soup = BeautifulSoup(driver.page_source, 'html.parser')
team_tables = soup.find_all('div', class_='table-scroll')
all_rows = []

for team_table in team_tables:
    headers = [header.text.strip() for header in team_table.find_all('th')]
    headers = headers[:10]
    rows = []
    for row in team_table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) > 0:
            row_data = [col.text.strip() for col in columns]
            rows.append(row_data)
    all_rows.extend(rows)

df = pd.DataFrame(all_rows, columns=headers)
driver.quit()

# Filtering for arm injuries and pitchers
filtered_df = df[df['Injury / Surgery'].str.contains('Tommy John|Elbow|Shoulder|Forearm', case=False, na=False)]
filtered_df_p = filtered_df[filtered_df['Pos'].str.contains('SP|RP', case=False, na=False)]

# Data cleaning
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '20", na=False), 'Injury / Surgery Date'] = '01/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '20", na=False), 'Injury / Surgery Date'] = '02/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '20", na=False), 'Injury / Surgery Date'] = '03/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '20", na=False), 'Injury / Surgery Date'] = '04/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '20", na=False), 'Injury / Surgery Date'] = '05/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '20", na=False), 'Injury / Surgery Date'] = '06/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '20", na=False), 'Injury / Surgery Date'] = '07/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '20", na=False), 'Injury / Surgery Date'] = '08/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '20", na=False), 'Injury / Surgery Date'] = '09/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '20", na=False), 'Injury / Surgery Date'] = '10/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '20", na=False), 'Injury / Surgery Date'] = '11/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '20", na=False), 'Injury / Surgery Date'] = '12/01/20'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '19", na=False), 'Injury / Surgery Date'] = '01/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '19", na=False), 'Injury / Surgery Date'] = '02/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '19", na=False), 'Injury / Surgery Date'] = '03/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar' 19", na=False), 'Injury / Surgery Date'] = '03/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '19", na=False), 'Injury / Surgery Date'] = '04/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '19", na=False), 'Injury / Surgery Date'] = '05/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '19", na=False), 'Injury / Surgery Date'] = '06/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '19", na=False), 'Injury / Surgery Date'] = '07/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul' 19", na=False), 'Injury / Surgery Date'] = '07/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '19", na=False), 'Injury / Surgery Date'] = '08/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '19", na=False), 'Injury / Surgery Date'] = '09/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '19", na=False), 'Injury / Surgery Date'] = '10/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '19", na=False), 'Injury / Surgery Date'] = '11/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '19", na=False), 'Injury / Surgery Date'] = '12/01/19'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '21", na=False), 'Injury / Surgery Date'] = '01/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '21", na=False), 'Injury / Surgery Date'] = '02/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Mar '21", na=False), 'Injury / Surgery Date'] = '03/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Apr '21", na=False), 'Injury / Surgery Date'] = '04/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("May '21", na=False), 'Injury / Surgery Date'] = '05/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jun '21", na=False), 'Injury / Surgery Date'] = '06/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jul '21", na=False), 'Injury / Surgery Date'] = '07/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Aug '21", na=False), 'Injury / Surgery Date'] = '08/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Sep '21", na=False), 'Injury / Surgery Date'] = '09/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Oct '21", na=False), 'Injury / Surgery Date'] = '10/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Nov '21", na=False), 'Injury / Surgery Date'] = '11/01/21'
filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Dec '21", na=False), 'Injury / Surgery Date'] = '12/01/21'
filtered_df_p = filtered_df_p.drop(936)
filtered_df_p['Injury / Surgery Date'] = pd.to_datetime(filtered_df_p['Injury / Surgery Date'], format='%m/%d/%y')
cutoff_date = pd.to_datetime('01/01/21', format='%m/%d/%y')
final_df_21 = filtered_df_p[filtered_df_p['Injury / Surgery Date'] > cutoff_date]

final_df_21.reset_index(drop=True)
# Out:
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/2537518615.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Jan '20", na=False), 'Injury / Surgery Date'] = '01/01/20'
# /var/folders/4d/9v04gb7d0z75_dg3gtdvtnz40000gn/T/ipykernel_59125/2537518615.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df_p.loc[filtered_df_p['Injury / Surgery Date'].str.contains("Feb '20", na=False), 'Injury / Surgery Date'] = '02/01/20'
# ...

# %%
total_inj_df = pd.concat([final_df_24, final_df_23, final_df_22, final_df_21], ignore_index=True)
total_inj_df
# Out:
#                    Name Team Pos Injury / Surgery Date       Injury / Surgery  \
# 0         Chase Silseth  LAA  SP            2024-04-07     Elbow inflammation
# 1          José Cisnero  LAA  RP            2024-04-27  Shoulder inflammation
# 2     Robert Stephenson  LAA  RP            2024-04-30     Tommy John surgery
# 3           Adam Cimber  LAA  RP            2024-06-14  Shoulder inflammation
# 4      Patrick Sandoval  LAA  SP            2024-06-26    Elbow surgery (UCL)
# ..                  ...  ...  ..                   ...                    ...
# 885  Anthony DeSclafani  SFG  SP            2021-08-02       Shoulder fatigue
# 886        Johnny Cueto  SFG  SP            2021-08-31         Strained elbow
# 887         Tony Watson  SFG  RP            2021-09-28      Strained shoulder
# 888       Dedniel Núñez  SFG  RP            2021-03-30     Tommy John surgery
# 889       Sam Delaplane  SFG  RP            2021-04-13     Tommy John surgery
#
# ...
